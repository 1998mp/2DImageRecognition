# %%
import cv2
import numpy as np
from  google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/img-000001.png")   
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # BGR -> RGB

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=730x530 at 0x7FB21160A050>

# %%
img[:,:,0] *= 50

# %%
img[:,:,1] *= 30

# %%
img[:,:,2] *= 10

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=730x530 at 0x7FB202285C90>

# %%
cv2.imwrite('/content/img-000001_colored.png', img)
